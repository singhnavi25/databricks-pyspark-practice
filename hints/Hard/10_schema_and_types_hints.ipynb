# %% [markdown]
# # Hints — Schema And Types
#
# **Level:** Hard
#
# > These hints are here when you're stuck. Try solving each problem on your own first.
# > Reveal one hint at a time — start with Problem 1 and work through in order.

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ## Problem 2

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Use `.select(F.col('transactionID').cast(T.LongType()), ...)`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 3

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# F.struct(F.col('city'), F.col('state'), F.col('country')).alias('address_struct')`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 4

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# T.StructType.fromDDL("orderkey BIGINT, ...")` returns a `StructType`. Then use `.select` with explicit casts.
# ```
#
# </details>

# %% [markdown]
# ## Problem 5

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Use `F.collect_list` for the array. For the map, first groupBy `[franchiseID, paymentMethod]`, count, then use `F.collect_list` + `F.map_from_arrays` in a second aggregation, or use `F.map_from_entries(F.collect_list(F.struct(...)))`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 6

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# F.col('customerID').cast(T.StringType()).alias('zip_as_string')`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 7

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Build a list of tuples and use `spark.createDataFrame(rows, schema)`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 8

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Build the change_log with `spark.createDataFrame([('ADD', 'discount_pct', 'default 0.0'), ...], [...])`.
# ```
#
# </details>
