# %% [markdown]
# # Hints — Udfs And Pandas Udfs
#
# **Level:** Hard
#
# > These hints are here when you're stuck. Try solving each problem on your own first.
# > Reveal one hint at a time — start with Problem 1 and work through in order.

# %% [markdown]
# ## Problem 1

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Decorate a plain Python function with `@F.udf(returnType=T.StringType())`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 2

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# UDFs can accept multiple column arguments when called: `my_udf(F.col('a'), F.col('b'))`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 3

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# str(card_number)[-4:]` gives the last 4; `'*' * (len - 4)` gives the mask.
# ```
#
# </details>

# %% [markdown]
# ## Problem 4

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# The function receives a `pd.Series` and must return a `pd.Series` of the same length. Use `(s - s.mean()) / s.std()`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 5

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# s.str.strip().str.title()` in pandas. Note that `str.title()` and `F.initcap` may differ slightly on hyphenated or multi-word strings — that is expected.
# ```
#
# </details>

# %% [markdown]
# ## Problem 6

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# The temp view `trips` was registered in the Setup cell.
# ```
#
# </details>

# %% [markdown]
# ## Problem 8
