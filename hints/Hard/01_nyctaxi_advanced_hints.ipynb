# %% [markdown]
# # Hints — Nyctaxi Advanced
#
# **Level:** Hard
#
# > These hints are here when you're stuck. Try solving each problem on your own first.
# > Hints are provided for selected problems - the trickier ones. If a problem is not listed here, it is meant to be solvable from the docs and earlier problems.
# > Reveal one hint at a time.

# %% [markdown]
# ## Problem 6

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# use `F.percentile_approx('fare_amount', [0.25, 0.5, 0.75, 0.95])` and then index the resulting array to extract `p25`, `p50`, `p75`, `p95`.
# ```
#
# </details>

# %% [markdown]
# ## Problem 8

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Use `F.date_trunc('day', ...)` for the date, then `Window.partitionBy('pickup_zip').orderBy(F.col('pickup_date').cast('long')).rangeBetween(-6*86400, 0)` for the rolling window.
# ```
#
# </details>
