# %% [markdown]
# # Hints — Wanderbricks Users
#
# **Level:** Easy
#
# > These hints are here when you're stuck. Try solving each problem on your own first.
# > Reveal one hint at a time.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# <details>
# <summary>Hint 1 — grouping by a boolean column</summary>
#
# Group by `is_business` directly — boolean columns work in groupBy:
# ```python
# df.groupBy("is_business").count()
# ```
# This gives two rows: one for `True`, one for `False`.
#
# </details>

# %% [markdown]
# ## Problem 3

# %% [markdown]
# <details>
# <summary>Hint 1 — extracting year from a timestamp and grouping</summary>
#
# ```python
# df.groupBy(F.year("created_at").alias("join_year")) \
#   .count() \
#   .orderBy("join_year")
# ```
#
# </details>
