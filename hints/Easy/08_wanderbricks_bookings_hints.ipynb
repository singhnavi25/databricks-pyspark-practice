# %% [markdown]
# # Hints — Wanderbricks Bookings
#
# **Level:** Easy
#
# > These hints are here when you're stuck. Try solving each problem on your own first.
# > Hints are provided for selected problems - the trickier ones. If a problem is not listed here, it is meant to be solvable from the docs and earlier problems.
# > Reveal one hint at a time.

# %% [markdown]
# ## Problem 5

# %% [markdown]
# <details>
# <summary>Hint 1 — computing duration from two date columns</summary>
#
# `F.datediff(end, start)` returns the number of days between two dates:
# ```python
# df.withColumn("stay_nights", F.datediff(F.col("check_out"), F.col("check_in")))
# ```
# Then group by `status` and average the `stay_nights` column.
#
# </details>
