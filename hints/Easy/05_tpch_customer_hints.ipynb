# %% [markdown]
# # Hints — TPC-H Customer
#
# **Level:** Easy
#
# > These hints are here when you're stuck. Try solving each problem on your own first.
# > Hints are provided for selected problems - the trickier ones. If a problem is not listed here, it is meant to be solvable from the docs and earlier problems.
# > Reveal one hint at a time.

# %% [markdown]
# ## Problem 3

# %% [markdown]
# <details>
# <summary>Hint 1 — multiple aggregations grouped by a string column</summary>
#
# ```python
# df.groupBy("c_mktsegment").agg(
#     F.round(F.avg("c_acctbal"), 2).alias("avg_balance"),
#     F.min("c_acctbal").alias("min_balance"),
#     F.max("c_acctbal").alias("max_balance")
# )
# ```
#
# </details>
