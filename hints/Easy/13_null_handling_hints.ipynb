# %% [markdown]
# # Hints — Null Handling
#
# **Level:** Easy
#
# > These hints are here when you're stuck. Try solving each problem on your own first.
# > Reveal one hint at a time — start with Problem 1 and work through in order.

# %% [markdown]
# ## Problem 1

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Build a list of `(column_name, null_count, null_rate_pct)` tuples, then use `spark.createDataFrame([...])` to build the summary DataFrame.
# ```
#
# </details>

# %% [markdown]
# ## Problem 2

# %% [markdown]
# <details>
# <summary>Hint 1 — two separate filter calls, two separate result variables</summary>
#
# Filter the same DataFrame twice — once for nulls, once for non-nulls:
# ```python
# result_2a = df.filter(F.col("state").isNull())
# result_2b = df.filter(F.col("state").isNotNull())
# ```
# Check the problem statement to see which variable name(s) the test expects.
#
# </details>

# %% [markdown]
# ## Problem 3

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# .fillna({"state": "Unknown", "gender": "Not Specified"})` fills multiple columns at once.
# ```
#
# </details>

# %% [markdown]
# ## Problem 4

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# F.coalesce(F.col("district"), F.col("city"), F.lit("Unknown"))` returns the first non-null value.
# ```
#
# </details>

# %% [markdown]
# ## Problem 5

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# ```python
# Call `.count()` before and after `.dropna()`, then build a small DataFrame using `spark.createDataFrame([...])`.
# ```
#
# </details>
